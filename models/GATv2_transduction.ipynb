# %% [markdown]
# # Neural network-based model for the identification of Bladder Cancers subtypes
#
# ## Transduction method

# %% [markdown]
# ### Pretreatment of the data:
# - necessary libraries imports
# - dataframe definition
# - dataframe sorting and cleaning

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
from torch_geometric.data import Data
from torch_geometric.nn import GATv2Conv

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

Dataframe_Labels = pd.read_csv("../data/labels_str.csv")
Dataframe_link = pd.read_csv("../data/patient_norm.csv")
Dataframe_node= pd.read_csv("../data/node_embedding.csv")

Dataframe_Labels['class_int'], uniques = pd.factorize(Dataframe_Labels['class'])
Dataframe_Labels
# Out:
#           Patient        class  class_int
# 0    TCGA-2F-A9KO         LumP          0
# 1    TCGA-2F-A9KP         LumP          0
# 2    TCGA-2F-A9KQ         LumP          0
# 3    TCGA-2F-A9KR        Ba/Sq          1
# 4    TCGA-2F-A9KT        Ba/Sq          1
# ..            ...          ...        ...
# 399  TCGA-ZF-AA56        Ba/Sq          1
# 400  TCGA-ZF-AA58        Ba/Sq          1
# 401  TCGA-ZF-AA5H        Ba/Sq          1
# 402  TCGA-ZF-AA5N         LumP          0
# 403  TCGA-ZF-AA5P  Stroma-rich          3
#
# [404 rows x 3 columns]

# %%
cancer_distribution = Dataframe_Labels['class'].value_counts()

# Plot the distribution of the classes
print(cancer_distribution)

plt.figure(figsize=(10, 6))
cancer_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution des différents types de cancers')
plt.xlabel('Type de cancer')
plt.ylabel('Nombre de patients')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# class
# Ba/Sq          153
# LumP           127
# LumU            53
# Stroma-rich     45
# LumNS           20
# NE-like          6
# Name: count, dtype: int64

# %% [markdown]
# We choose to delete the patient having the last two cancers due to a low number fo data.

# %%
# Dataframe definition
Dataframe_Labels = pd.read_csv("../data/labels_str.csv")          # Contains the labels of each patient (=cancer)
Dataframe_link = pd.read_csv("../data/patient_norm.csv")          # Contains the clinic datas of each patient (will be used for link initialization)
Dataframe_node = pd.read_csv("../data/node_embedding.csv")        # Contains the omic datas of each patient (will be used for node initialization)

# Adding a column to associate each class to a integer
Dataframe_Labels['class_int'], uniques = pd.factorize(Dataframe_Labels['class'])

# Filtering the dataframe to get rid of the two last classes (not enough datas)
Dataframe_Labels = Dataframe_Labels[~Dataframe_Labels['class_int'].isin([4, 5])]

patients_to_keep = Dataframe_Labels['Patient'].unique()
Dataframe_link = Dataframe_link[Dataframe_link['Patient'].isin(patients_to_keep)]
Dataframe_node = Dataframe_node[Dataframe_node['Patient'].isin(patients_to_keep)]

# Reset the labels to get clean Dataframes
Dataframe_Labels = Dataframe_Labels.reset_index(drop=True)
Dataframe_link = Dataframe_link.reset_index(drop=True)
Dataframe_node = Dataframe_node.reset_index(drop=True)

# %% [markdown]
# ### Graph initialization (weight, nodes and links)
#
# Each weight is defined following this formula :
# $$\mu = \text{mean of the number of patient victim of a type of cancer}$$
# $$n_i = \text{number of victim of each cancer}$$
# $$w_i = \text{weight of the ith class}$$
#
# $$w_i = \frac{\frac{\mu}{n_i}}{\sum \left( \frac{\mu}{n_j} \right)}$$

# %%
classes_dict = {0: 'LumP', 
                1: 'Ba/Sq', 
                2: 'LumU', 
                3: 'Stroma-rich'
}

def count_classes_weights(tensor):
    array = tensor.numpy()
    classes_tab = { 0: 0, 
                    1: 0,
                    2: 0, 
                    3: 0
    }
    for i in array:
        classes_tab[i]+=1

    mean_nb_classes = 0
    for i in classes_tab:
        mean_nb_classes += i
    mean_nb_classes *= 1/len(classes_tab)
    
    # normalize the weights
    weight_sum = 0
    for i in range(len(classes_tab)):
        if classes_tab[i] != 0:
            weight_sum += mean_nb_classes / classes_tab[i]
    alpha = 1 / weight_sum

    weight_dict = {}
    used_classes = []
    for i in range(len(classes_tab)):
        if classes_tab[i] != 0:
            weight_dict[i] = alpha * (mean_nb_classes / classes_tab[i]) *50
            used_classes.append(classes_dict[i])

    return used_classes, weight_dict

# %% [markdown]
# Nodes and links initialization :

# %%
from sklearn.model_selection import train_test_split

node_features = Dataframe_node.drop(columns=['Patient']).values
node_features = torch.tensor(node_features, dtype=torch.float)

train_val_indices = [i for i in range(node_features.shape[0])]
_, test_indices = train_test_split(
    range(len(node_features)), 
    test_size=0.2, 
    random_state=12345
)

x_train = node_features[train_val_indices]
x_test = node_features[test_indices]

patient_similarity = cosine_similarity(Dataframe_link.iloc[:, 1:])
similarity_threshold = 0.5  # Exemple de seuil de similarité

# Calculate the edges and attention ridges for training
edge_index_for_training = []
edge_attr_for_training = []
re_indexed_i = 0
re_indexed_j = 0
for i in range(len(train_val_indices)):
    for j in range(i+1, len(train_val_indices)):
        if patient_similarity[i, j] > similarity_threshold:
            edge_index_for_training.append([re_indexed_i, re_indexed_j])
            edge_attr_for_training.append((patient_similarity[i, j] - similarity_threshold)/(1 - similarity_threshold))
        re_indexed_j +=1
    re_indexed_i +=1
    re_indexed_j = 0

# Calculate the edges and attention ridges for testing
edge_index_for_testing = []
edge_attr_for_testing = []
re_indexed_i = 0
re_indexed_j = 0
for i in test_indices:
    for j in test_indices:
        if i >= j :
            break
        if patient_similarity[i, j] > similarity_threshold:
            edge_index_for_testing.append([re_indexed_i, re_indexed_j])
            edge_attr_for_testing.append((patient_similarity[i, j] - similarity_threshold)/(1 - similarity_threshold))
        re_indexed_j +=1
    re_indexed_i +=1
    re_indexed_j = 0

# %%
# Setting the labels of each node
node_labels = Dataframe_Labels["class_int"].values
train_labels = torch.tensor(node_labels[train_val_indices], dtype=torch.long)
test_labels = torch.tensor(node_labels[test_indices], dtype=torch.long)

# %%
# Setting the weight
node_labels = torch.tensor(node_labels, dtype=torch.long)

used_classes, weight_dict = count_classes_weights(node_labels)
Dataframe_Labels['weight'] = [weight_dict[x] for x in Dataframe_Labels['class_int']]
node_weights = torch.tensor(Dataframe_Labels['weight'], dtype=torch.float)

# %%
# Setting the features, connexions (edge_index and edge _attr) and weight of each nodes
edge_features_for_training = torch.tensor(x_train, dtype=torch.float)
edge_index_for_training = torch.tensor(edge_index_for_training, dtype=torch.int64).t().contiguous()
edge_attr_for_training = torch.tensor(edge_attr_for_training, dtype=torch.float)
node_weights_for_training = node_weights[train_val_indices]

edge_features_for_testing = torch.tensor(x_test, dtype=torch.float)
edge_index_for_testing = torch.tensor(edge_index_for_testing, dtype=torch.int64).t().contiguous()
edge_attr_for_testing = torch.tensor(edge_attr_for_testing, dtype=torch.float)
node_weights_for_testing = node_weights[test_indices]
# Out:
# /tmp/ipykernel_90266/2918634406.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   edge_features_for_training = torch.tensor(x_train, dtype=torch.float)
# /tmp/ipykernel_90266/2918634406.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   edge_features_for_testing = torch.tensor(x_test, dtype=torch.float)

# %%
# Data object definition

num_classes = 4
test_mask = torch.zeros(len(edge_features_for_training), dtype=torch.bool)
test_mask[test_indices] = True

train_val_data = Data(
    x=edge_features_for_training,                       # node informations 
    edge_index=edge_index_for_training,                 # node connexions (which nodes are connected)
    edge_attr=edge_attr_for_training,                   # node connexions (importance of each connexion)
    y=train_labels,                                     # node labels
    weights=node_weights_for_training,                  # node weight
    num_classes=num_classes,                            # number of classes in the graph
    num_nodes = len(edge_features_for_training),        # number of nodes
    num_features = edge_features_for_training.shape[1], # number of features
    test_mask = test_mask                               # test_mask (indices of test graph)
)
print(train_val_data)

test_data = Data(
    x=edge_features_for_testing,                        # node informations 
    edge_index=edge_index_for_testing,                  # node connexions (which nodes are connected)
    edge_attr=edge_attr_for_testing,                    # node connexions (importance of each connexion)
    y=test_labels,                                      # node labels
    weights=node_weights_for_testing,                   # node weight
    num_classes=num_classes,                            # number of classes in the graph
    num_nodes = len(edge_features_for_testing),         # number of nodes
    num_features = edge_features_for_testing.shape[1]   # number of features
    )
print(test_data)
# Out:
# Data(x=[378, 825], edge_index=[2, 42291], edge_attr=[42291], y=[378], weights=[378], num_classes=4, num_nodes=378, num_features=825, test_mask=[378])
# Data(x=[76, 825], edge_index=[2, 165], edge_attr=[165], y=[76], weights=[76], num_classes=4, num_nodes=76, num_features=825)

# %% [markdown]
# ### Graph neural network definition: GATv2
#
# source code available at: https://github.com/tech-srl/how_attentive_are_gats

# %%
# GATv2 initialization
class GATv2(torch.nn.Module):
    def __init__(self, hidden_channels, heads, data):
        super(GATv2, self).__init__()
        torch.manual_seed(1234)
        self.conv1 = GATv2Conv(data.num_features, hidden_channels, heads=heads, edge_dim=1)
        self.conv2 = GATv2Conv(hidden_channels * heads, data.num_classes, edge_dim=1)
        
    def forward(self, x, edge_index, edge_attr):
        x = F.dropout(x, p=0.6, training=self.training)
        x = self.conv1(x, edge_index, edge_attr)
        x = F.elu(x)
        x = F.dropout(x, p=0.6, training=self.training)
        x = self.conv2(x, edge_index, edge_attr)
        return x
    
# Entropy loss function
def weighted_cross_entropy_loss(output, target, weights):
    loss = F.cross_entropy(output, target, reduction='none')
    weighted_loss = loss * weights[target]
    return weighted_loss.mean()

# Train function
def train(model, data, optimizer):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index, data.edge_attr)
    loss = weighted_cross_entropy_loss(out[data.train_mask], data.y[data.train_mask], data.weights[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss, model

# Test function
def test(model, data, mask):
    model.eval()
    out = model(data.x, data.edge_index, data.edge_attr)
    pred = out.argmax(dim=1)
    correct = pred[mask] == data.y[mask]
    acc = int(correct.sum()) / int(mask.sum())
    return acc, pred[mask]

# Distinction function, this function will make sure the validation set and the test set are different
def distinction(data):
    train_val_indexes = torch.ones(data.num_nodes, dtype=torch.bool)
    for i in range(len(train_val_indexes)):
        if data.test_mask[i]:
            train_val_indexes[i] = False

    X=data.x[train_val_indexes]
    Y=data.y[train_val_indexes]
    return(X,Y)

# %% [markdown]
# ### Construction : Transduction method
#
# The transduction method consists in building one graph and hiding the label of some nodes for testing and validation. The learning is done on the graph with the nodes linked to each other.

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
import seaborn as sn

def cross_validation(data, k_folds, hidden_channels, heads, num_epochs=1000):
    skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=1234)
    all_val_acc = []

    val_acc_best = 0
    data_X_for_Val, data_Y_for_val  = distinction(data)

    # Create folds for building a more robust model
    for fold, (_, val_index) in enumerate(skf.split(data_X_for_Val, data_Y_for_val)):

        # Define masks
        train_index = [i for i in range(data.num_nodes)]
        data.train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
        data.train_mask[train_index] = True
        
        data.val_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
        data.val_mask[val_index] = True
        
        train_classes, _ = count_classes_weights(data.y[data.train_mask])
        val_classes, _ = count_classes_weights(data.y[data.val_mask])

        # Initialize model, optimizer, and loss function
        model = GATv2(hidden_channels=hidden_channels, heads=heads, data=data)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

        lost_function_compil = []
        all_val_acc_plot = []

        # Training loop
        for epoch in range(1, num_epochs):
            loss, model = train(model, data, optimizer)
            train_acc, _ = test (model, data, data.train_mask)
            val_acc, _ = test(model, data, data.val_mask)
            lost_function_compil.append(loss.detach().tolist())
            all_val_acc_plot.append(val_acc)
            print(f'Fold: {fold + 1}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Train_acc {train_acc:.4f}, Val_acc {val_acc:.4f}')

        # Evaluate on validation set
        val_acc, y_pred = test(model, data, data.val_mask)
        y_true = data.y[data.val_mask]

        # Store results
        all_val_acc.append(val_acc)
        conf_matrix = confusion_matrix(y_true.cpu().tolist(), y_pred.cpu().tolist())
        
        # Setting the best model through the folds
        if val_acc > val_acc_best:
            best_model = model

        # Plot confusion matrix
        conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
        df_cm = pd.DataFrame(conf_matrix_normalized, index=train_classes, columns=train_classes)  
        sn.heatmap(df_cm, annot=True)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title('Confusion Matrix on Validation')
        plt.show()

        # Plot the loss function and the accuracy improvement
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

        ax1.plot(range(len(lost_function_compil)), lost_function_compil, label='Loss')
        ax1.set_xlabel('Epochs')
        ax1.set_ylabel('Loss')
        ax1.set_title('Loss Function over Epochs')
        ax1.legend()

        ax2.plot(range(len(all_val_acc_plot)), all_val_acc_plot, label='val_accuracy')
        ax2.set_xlabel('Epochs')
        ax2.set_ylabel('val_accuracy')
        ax2.set_title('val_accuracy over Epochs')
        ax2.legend()

        plt.show()

    # Calculate and print overall metrics
    mean_val_acc = np.mean(all_val_acc)
    std_val_acc = np.std(all_val_acc)
    print(f'Mean Validation Accuracy: {mean_val_acc:.4f}, Std Validation Accuracy: {std_val_acc:.4f}')

    return best_model

# Training phase
best_model = cross_validation(train_val_data, k_folds=5, hidden_channels=20, heads=8, num_epochs=1250)
# Out:
# Fold: 1, Epoch: 001, Loss: 9.1995, Train_acc 0.4048, Val_acc 0.4918
# Fold: 1, Epoch: 002, Loss: 21.0611, Train_acc 0.1190, Val_acc 0.1475
# Fold: 1, Epoch: 003, Loss: 17.1621, Train_acc 0.1190, Val_acc 0.1475
# Fold: 1, Epoch: 004, Loss: 10.0641, Train_acc 0.3360, Val_acc 0.2459
# Fold: 1, Epoch:
Train_acc 0.3519, Val_acc 0.2459
# Fold: 1, Epoch: 656, Loss: 4.9050, Train_acc 0.3492, Val_acc 0.2459
# Fold: 1, Epoch: 657, Loss: 4.8962, Train_acc 0.3492, Val_acc 0.2459
# Fold: 1, Epoch: 658, Loss: 5.2724, Train_acc 0.3492, Val_acc 0.2459
# Fold: 1, Epoch: 659, Loss: 4.7939, Train_acc 0.3492, Val_acc 0.2459
# Fold: 1, Epoch: 660, Loss: 5.1740, Train_acc 0.3519, Val_acc 0.2459
# Fold: 1, Epoch: 661, Loss: 4.7332, Train_acc 0.3571, Val_acc 0.2459
# Fold: 1, Epoch: 662, Loss: 4.8051, Train_acc 0.5238, Val_acc 0.4262
# Fold: 1, Epoch: 663, Loss: 4.8533, Train_acc 0.7196, Val_acc 0.6885
# Fold: 1, Epoch: 664, Loss: 4.8592, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 665, Loss: 4.9780, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 666, Loss: 5.3436, Train_acc 0.7249, Val_acc 0.6885
# Fold: 1, Epoch: 667, Loss: 4.3612, Train_acc 0.7222, Val_acc 0.6885
# Fold: 1, Epoch: 668, Loss: 4.5845, Train_acc 0.7196, Val_acc 0.6721
# Fold: 1, Epoch: 669, Loss: 4.7573, Train_acc 0.7196, Val_acc 0.6721
# Fold: 1, Epoch: 670, Loss: 4.6694, Train_acc 0.7222, Val_acc 0.6885
# Fold: 1, Epoch: 671, Loss: 4.8412, Train_acc 0.7222, Val_acc 0.6885
# Fold: 1, Epoch: 672, Loss: 4.7198, Train_acc 0.7249, Val_acc 0.6885
# Fold: 1, Epoch: 673, Loss: 4.5252, Train_acc 0.7275, Val_acc 0.6885
# Fold: 1, Epoch: 674, Loss: 4.6305, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 675, Loss: 4.7019, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 676, Loss: 4.2463, Train_acc 0.7275, Val_acc 0.7049
# Fold: 1, Epoch: 677, Loss: 4.7392, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 678, Loss: 4.7667, Train_acc 0.7328, Val_acc 0.7049
# Fold: 1, Epoch: 679, Loss: 4.4901, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 680, Loss: 4.6142, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 681, Loss: 4.5932, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 682, Loss: 4.6254, Train_acc 0.7328, Val_acc 0.7049
# Fold: 1, Epoch: 683, Loss: 4.3513, Train_acc 0.7302, Val_acc 0.7049
# Fold: 1, Epoch: 684, Loss: 4.4108, Train_acc 0.7328, Val_acc 0.7049
# Fold: 1, Epoch: 685, Loss: 4.6864, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 686, Loss: 4.3835, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 687, Loss: 4.4726, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 688, Loss: 4.4347, Train_acc 0.7381, Val_acc 0.7213
# Fold: 1, Epoch: 689, Loss: 4.7518, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 690, Loss: 5.0591, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 691, Loss: 4.6197, Train_acc 0.7328, Val_acc 0.7049
# Fold: 1, Epoch: 692, Loss: 4.4000, Train_acc 0.7249, Val_acc 0.7049
# Fold: 1, Epoch: 693, Loss: 4.9651, Train_acc 0.7328, Val_acc 0.7049
# Fold: 1, Epoch: 694, Loss: 4.4504, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 695, Loss: 4.4077, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 696, Loss: 5.2006, Train_acc 0.7381, Val_acc 0.7213
# Fold: 1, Epoch: 697, Loss: 4.8889, Train_acc 0.7381, Val_acc 0.7213
# Fold: 1, Epoch: 698, Loss: 4.6120, Train_acc 0.7381, Val_acc 0.7213
# Fold: 1, Epoch: 699, Loss: 4.3820, Train_acc 0.7381, Val_acc 0.7213
# Fold: 1, Epoch: 700, Loss: 4.3127, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 701, Loss: 4.5629, Train_acc 0.7354, Val_acc 0.7213
# Fold: 1, Epoch: 702, Loss: 4.2587, Train_acc 0.7328, Val_acc 0.7049
# Fold: 1, Epoch: 703, Loss: 4.3802, Train_acc 0.7328, Val_acc 0.7049
# Fold: 1, Epoch: 704, Loss: 4.3400, Train_acc 0.7328, Val_acc 0.7049
# Fold: 1, Epoch: 705, Loss: 4.5456, Train_acc 0.7328, Val_acc 0.7049
# ...
# Fold: 5, Epoch: 1020, Loss: 1.1022, Train_acc 0.6905, Val_acc 0.7667
# Fold: 5, Epoch: 1021, Loss: 0.8719, Train_acc 0.6614, Val_acc 0.7333
# Fold: 5, Epoch: 1022, Loss: 1.5194, Train_acc 0.6534, Val_acc 0.7167
# Fold: 5, Epoch: 1023, Loss: 1.2299, Train_acc 0.6772, Val_acc 0.7500
# Fold: 5, Epoch: 1024, Loss: 0.9052, Train_acc 0.7037, Val_acc 0.7833
# Fold: 5, Epoch: 1025, Loss: 0.8520, Train_acc 0.7619, Val_acc 0.8500
# Fold: 5, Epoch: 1026, Loss: 1.1875, Train_acc 0.7910, Val_acc 0.8500
# Fold: 5, Epoch: 1027, Loss: 1.0556, Train_acc 0.7460, Val_acc 0.8333
# Fold: 5, Epoch: 1028, Loss: 1.1080, Train_acc 0.6799, Val_acc 0.7333
# Fold: 5, Epoch: 1029, Loss: 1.7780, Train_acc 0.6270, Val_acc 0.7167
# Fold: 5, Epoch: 1030, Loss: 1.2931, Train_acc 0.6085, Val_acc 0.6667
# Fold: 5, Epoch: 1031, Loss: 1.6010, Train_acc 0.6058, Val_acc 0.6500
# Fold: 5, Epoch: 1032, Loss: 1.7356, Train_acc 0.6111, Val_acc 0.6500
# Fold: 5, Epoch: 1033, Loss: 1.3043, Train_acc 0.6111, Val_acc 0.6500
# Fold: 5, Epoch: 1034, Loss: 1.4958, Train_acc 0.6455, Val_acc 0.7000
# Fold: 5, Epoch: 1035, Loss: 0.8240, Train_acc 0.6667, Val_acc 0.7333
# Fold: 5, Epoch: 1036, Loss: 1.4075, Train_acc 0.6746, Val_acc 0.7333
# Fold: 5, Epoch: 1037, Loss: 1.2043, Train_acc 0.6587, Val_acc 0.7500
# Fold: 5, Epoch: 1038, Loss: 1.5327, Train_acc 0.6376, Val_acc 0.7167
# Fold: 5, Epoch: 1039, Loss: 1.1722, Train_acc 0.6349, Val_acc 0.7000
# Fold: 5, Epoch: 1040, Loss: 1.1110, Train_acc 0.6323, Val_acc 0.7000
# Fold: 5, Epoch: 1041, Loss: 1.2541, Train_acc 0.6587, Val_acc 0.7167
# Fold: 5, Epoch: 1042, Loss: 1.4664, Train_acc 0.6825, Val_acc 0.7500
# Fold: 5, Epoch: 1043, Loss: 1.0284, Train_acc 0.7725, Val_acc 0.8500
# Fold: 5, Epoch: 1044, Loss: 1.5598, Train_acc 0.9074, Val_acc 0.9000
# Fold: 5, Epoch: 1045, Loss: 1.3622, Train_acc 0.9312, Val_acc 0.9500
# Fold: 5, Epoch: 1046, Loss: 1.5674, Train_acc 0.9339, Val_acc 0.9333
# Fold: 5, Epoch: 1047, Loss: 1.3788, Train_acc 0.8519, Val_acc 0.8833
# Fold: 5, Epoch: 1048, Loss: 0.9412, Train_acc 0.7381, Val_acc 0.8500
# Fold: 5, Epoch: 1049, Loss: 1.2937, Train_acc 0.6693, Val_acc 0.7667
# Fold: 5, Epoch: 1050, Loss: 1.3625, Train_acc 0.6561, Val_acc 0.7500
# Fold: 5, Epoch: 1051, Loss: 1.6036, Train_acc 0.6667, Val_acc 0.7333
# Fold: 5, Epoch: 1052, Loss: 1.1894, Train_acc 0.6693, Val_acc 0.7333
# Fold: 5, Epoch: 1053, Loss: 1.4446, Train_acc 0.6720, Val_acc 0.7333
# Fold: 5, Epoch: 1054, Loss: 1.1724, Train_acc 0.6614, Val_acc 0.7333
# Fold: 5, Epoch: 1055, Loss: 1.3165, Train_acc 0.6323, Val_acc 0.7000
# Fold: 5, Epoch: 1056, Loss: 1.5330, Train_acc 0.6085, Val_acc 0.6500
# Fold: 5, Epoch: 1057, Loss: 0.9923, Train_acc 0.6111, Val_acc 0.6500
# Fold: 5, Epoch: 1058, Loss: 1.1173, Train_acc 0.6111, Val_acc 0.6500
# Fold: 5, Epoch: 1059, Loss: 1.2177, Train_acc 0.6111, Val_acc 0.6500
# Fold: 5, Epoch: 1060, Loss: 1.2888, Train_acc 0.6138, Val_acc 0.6667
# Fold: 5, Epoch: 1061, Loss: 1.5947, Train_acc 0.6402, Val_acc 0.7167
# Fold: 5, Epoch: 1062, Loss: 1.0063, Train_acc 0.6931, Val_acc 0.7500
# Fold: 5, Epoch: 1063, Loss: 0.8654, Train_acc 0.7302, Val_acc 0.7833
# Fold: 5, Epoch: 1064, Loss: 1.3722, Train_acc 0.7328, Val_acc 0.8000
# Fold: 5, Epoch: 1065, Loss: 1.1335, Train_acc 0.7222, Val_acc 0.8000
# Fold: 5, Epoch: 1066, Loss: 1.0901, Train_acc 0.7037, Val_acc 0.8000
# Fold: 5, Epoch: 1067, Loss: 1.3890, Train_acc 0.6931, Val_acc 0.7667
# Fold: 5, Epoch: 1068, Loss: 1.1245, Train_acc 0.6720, Val_acc 0.7500
# Fold: 5, Epoch: 1069, Loss: 1.3106, Train_acc 0.6429, Val_acc 0.7333
# Fold: 5, Epoch: 1070, Loss: 0.9823, Train_acc 0.6190, Val_acc 0.7000
# Fold: 5, Epoch: 1071, Loss: 1.2283, Train_acc 0.6111, Val_acc 0.6667
# Fold: 5, Epoch: 1072, Loss: 1.5057, Train_acc 0.6296, Val_acc 0.7167
# Fold: 5, Epoch: 1073, Loss: 0.9946, Train_acc 0.6534, Val_acc 0.7500
# Fold: 5, Epoch: 1074, Loss: 1.3780, Train_acc 0.7487, Val_acc 0.8333
# Fold: 5, Epoch: 1075, Loss: 1.1659, Train_acc 0.8624, Val_acc 0.9000
# Fold: 5, Epoch: 1076, Loss: 1.2012, Train_acc 0.8915, Val_acc 0.9167
# Fold: 5, Epoch: 1077, Loss: 1.1812, Train_acc 0.8810, Val_acc 0.9167
# Fold: 5, Epoch: 1078, Loss: 0.9424, Train_acc 0.8439, Val_acc 0.9000
# Fold: 5, Epoch: 1079, Loss: 1.3676, Train_acc 0.7302, Val_acc 0.8333
# Fold: 5, Epoch: 1080, Loss: 1.1578, Train_acc 0.6587, Val_acc 0.7333
# Fold: 5, Epoch: 1081, Loss: 1.0376, Train_acc 0.6270, Val_acc 0.7000
# Fold: 5, Epoch: 1082, Loss: 1.9002, Train_acc 0.6481, Val_acc 0.7333
# Fold: 5, Epoch: 1083, Loss: 1.5516, Train_acc 0.6772, Val_acc 0.7333
# Fold: 5, Epoch: 1084, Loss: 1.2333, Train_acc 0.7222, Val_acc 0.8333
# Fold: 5, Epoch: 1085, Loss: 1.5552, Train_acc 0.8333, Val_acc 0.9167
# Fold: 5, Epoch: 1086, Loss: 0.9447, Train_acc 0.8968, Val_acc 0.9500
# Fold: 5, Epoch: 1087, Loss: 1.0676, Train_acc 0.9180, Val_acc 0.9500
# Fold: 5, Epoch: 1088, Loss: 1.4089, Train_acc 0.9153, Val_acc 0.9333
# Fold: 5, Epoch: 1089, Loss: 0.8935, Train_acc 0.8810, Val_acc 0.9333
# Fold: 5, Epoch: 1090, Loss: 0.9515, Train_acc 0.8228, Val_acc 0.8667
# Fold: 5, Epoch: 1091, Loss: 1.4514, Train_acc 0.7354, Val_acc 0.8333
# Fold: 5, Epoch: 1092, Loss: 1.1324, Train_acc 0.6693, Val_acc 0.7500
# Fold: 5, Epoch: 1093, Loss: 1.9655, Train_acc 0.6587, Val_acc 0.7500
# Fold: 5, Epoch: 1094, Loss: 1.0802, Train_acc 0.6508, Val_acc 0.7500
# Fold: 5, Epoch: 1095, Loss: 1.3986, Train_acc 0.6508, Val_acc 0.7500
# Fold: 5, Epoch: 1096, Loss: 1.1732, Train_acc 0.6587, Val_acc 0.7500
# Fold: 5, Epoch: 1097, Loss: 1.5051, Train_acc 0.6746, Val_acc 0.7500
# Fold: 5, Epoch: 1098, Loss: 0.7287, Train_acc 0.6931, Val_acc 0.8000
# Fold: 5, Epoch: 1099, Loss: 0.6858, Train_acc 0.7090, Val_acc 0.8167
# Fold: 5, Epoch: 1100, Loss: 1.2213, Train_acc 0.7169, Val_acc 0.8333
# Fold: 5, Epoch: 1101, Loss: 1.0068, Train_acc 0.7487, Val_acc 0.8333
# Fold: 5, Epoch: 1102, Loss: 0.9801, Train_acc 0.7593, Val_acc 0.8333
# Fold: 5, Epoch: 1103, Loss: 0.9434, Train_acc 0.7698, Val_acc 0.8500
# Fold: 5, Epoch: 1104, Loss: 1.1577, Train_acc 0.8228, Val_acc 0.8667
# Fold: 5, Epoch: 1105, Loss: 1.3860, Train_acc 0.8175, Val_acc 0.8833
# Fold: 5, Epoch: 1106, Loss: 1.2968, Train_acc 0.8095, Val_acc 0.8833
# Fold: 5, Epoch: 1107, Loss: 1.1563, Train_acc 0.7698, Val_acc 0.8500
# Fold: 5, Epoch: 1108, Loss: 0.8447, Train_acc 0.7381, Val_acc 0.8333
# Fold: 5, Epoch: 1109, Loss: 1.2203, Train_acc 0.7275, Val_acc 0.8333
# Fold: 5, Epoch: 1110, Loss: 1.2663, Train_acc 0.6825, Val_acc 0.7500
# Fold: 5, Epoch: 1111, Loss: 1.2871, Train_acc 0.6534, Val_acc 0.7167
# Fold: 5, Epoch: 1112, Loss: 1.2467, Train_acc 0.6376, Val_acc 0.7000
# Fold: 5, Epoch: 1113, Loss: 0.8526, Train_acc 0.6349, Val_acc 0.7000
# Fold: 5, Epoch: 1114, Loss: 1.1403, Train_acc 0.6534, Val_acc 0.7167
# Fold: 5, Epoch: 1115, Loss: 0.8076, Train_acc 0.6852, Val_acc 0.7833
# Fold: 5, Epoch: 1116, Loss: 0.8445, Train_acc 0.7249, Val_acc 0.8000
# Fold: 5, Epoch: 1117, Loss: 1.0177, Train_acc 0.8148, Val_acc 0.8833
# Fold: 5, Epoch: 1118, Loss: 1.1880, Train_acc 0.8386, Val_acc 0.8833
# Fold: 5, Epoch: 1119, Loss: 1.5882, Train_acc 0.8280, Val_acc 0.8333
# Fold: 5, Epoch: 1120, Loss: 1.4633, Train_acc 0.8333, Val_acc 0.8833
# Fold: 5, Epoch: 1121, Loss: 0.7989, Train_acc 0.8175, Val_acc 0.8833
# Fold: 5, Epoch: 1122, Loss: 1.1493, Train_acc 0.7116, Val_acc 0.7833
# Fold: 5, Epoch: 1123, Loss: 0.9389, Train_acc 0.6296, Val_acc 0.7000
# Fold: 5, Epoch: 1124, Loss: 1.2147, Train_acc 0.6085, Val_acc 0.6500
# Fold: 5, Epoch: 1125, Loss: 1.2180, Train_acc 0.6085, Val_acc 0.6500
# Fold: 5, Epoch: 1126, Loss: 1.1409, Train_acc 0.6085, Val_acc 0.6500
# Fold: 5, Epoch: 1127, Loss: 1.1989, Train_acc 0.6111, Val_acc 0.6500
# Fold: 5, Epoch: 1128, Loss: 1.2525, Train_acc 0.6323, Val_acc 0.6667
# Fold: 5, Epoch: 1129, Loss: 1.0055, Train_acc 0.7063, Val_acc 0.7667
# Fold: 5, Epoch: 1130, Loss: 1.1063, Train_acc 0.7884, Val_acc 0.8333
# Fold: 5, Epoch: 1131, Loss: 0.8845, Train_acc 0.8386, Val_acc 0.8500
# Fold: 5, Epoch: 1132, Loss: 0.9473, Train_acc 0.8783, Val_acc 0.8667
# Fold: 5, Epoch: 1133, Loss: 1.0555, Train_acc 0.8571, Val_acc 0.8500
# Fold: 5, Epoch: 1134, Loss: 0.9105, Train_acc 0.7328, Val_acc 0.8000
# Fold: 5, Epoch: 1135, Loss: 1.4685, Train_acc 0.6402, Val_acc 0.7000
# Fold: 5, Epoch: 1136, Loss: 1.1173, Train_acc 0.6138, Val_acc 0.6667
# Fold: 5, Epoch: 1137, Loss: 1.2555, Train_acc 0.6138, Val_acc 0.6667
# Fold: 5, Epoch: 1138, Loss: 1.0764, Train_acc 0.6138, Val_acc 0.6667
# Fold: 5, Epoch: 1139, Loss: 0.8373, Train_acc 0.6270, Val_acc 0.6833
# Fold: 5, Epoch: 1140, Loss: 0.9401, Train_acc 0.6270, Val_acc 0.6667
# Fold: 5, Epoch: 1141, Loss: 0.6771, Train_acc 0.6323, Val_acc 0.6833
# Fold: 5, Epoch: 1142, Loss: 0.9664, Train_acc 0.6429, Val_acc 0.7000
# Fold: 5, Epoch: 1143, Loss: 0.8921, Train_acc 0.6746, Val_acc 0.7500
# Fold: 5, Epoch: 1144, Loss: 1.2852, Train_acc 0.7090, Val_acc 0.7667
# Fold: 5, Epoch: 1145, Loss: 1.0281, Train_acc 0.7222, Val_acc 0.7833
# Fold: 5, Epoch: 1146, Loss: 1.2620, Train_acc 0.6693, Val_acc 0.7500
# Fold: 5, Epoch: 1147, Loss: 0.9103, Train_acc 0.6323, Val_acc 0.7000
# Fold: 5, Epoch: 1148, Loss: 0.8915, Train_acc 0.6111, Val_acc 0.6500
# Fold: 5, Epoch: 1149, Loss: 0.8876, Train_acc 0.6138, Val_acc 0.6667
# Fold: 5, Epoch: 1150, Loss: 1.0531, Train_acc 0.6164, Val_acc 0.6667
# Fold: 5, Epoch: 1151, Loss: 1.0335, Train_acc 0.6138, Val_acc 0.6667
# Fold: 5, Epoch: 1152, Loss: 0.6891, Train_acc 0.6190, Val_acc 0.6667
# Fold: 5, Epoch: 1153, Loss: 1.3676, Train_acc 0.6296, Val_acc 0.7167
# Fold: 5, Epoch: 1154, Loss: 0.6923, Train_acc 0.6349, Val_acc 0.7167
# Fold: 5, Epoch: 1155, Loss: 0.9376, Train_acc 0.6455, Val_acc 0.7167
# Fold: 5, Epoch: 1156, Loss: 1.1661, Train_acc 0.6402, Val_acc 0.7167
# Fold: 5, Epoch: 1157, Loss: 0.9669, Train_acc 0.6455, Val_acc 0.7167
# Fold: 5, Epoch: 1158, Loss: 0.9472, Train_acc 0.6481, Val_acc 0.7167
# Fold: 5, Epoch: 1159, Loss: 1.0052, Train_acc 0.6772, Val_acc 0.7500
# Fold: 5, Epoch: 1160, Loss: 0.6801, Train_acc 0.7063, Val_acc 0.7667
# Fold: 5, Epoch: 1161, Loss: 0.8120, Train_acc 0.7354, Val_acc 0.8333
# Fold: 5, Epoch: 1162, Loss: 0.8400, Train_acc 0.7354, Val_acc 0.8333
# Fold: 5, Epoch: 1163, Loss: 0.7081, Train_acc 0.7116, Val_acc 0.7667
# Fold: 5, Epoch: 1164, Loss: 0.8412, Train_acc 0.7037, Val_acc 0.7667
# Fold: 5, Epoch: 1165, Loss: 1.0123, Train_acc 0.6799, Val_acc 0.7667
# Fold: 5, Epoch: 1166, Loss: 0.9980, Train_acc 0.6693, Val_acc 0.7500
# Fold: 5, Epoch: 1167, Loss: 1.0488, Train_acc 0.6746, Val_acc 0.7333
# Fold: 5, Epoch: 1168, Loss: 0.8628, Train_acc 0.6852, Val_acc 0.7667
# Fold: 5, Epoch: 1169, Loss: 0.9006, Train_acc 0.6693, Val_acc 0.7167
# Fold: 5, Epoch: 1170, Loss: 1.0756, Train_acc 0.6270, Val_acc 0.6833
# Fold: 5, Epoch: 1171, Loss: 0.9898, Train_acc 0.6138, Val_acc 0.6500
# Fold: 5, Epoch: 1172, Loss: 0.6627, Train_acc 0.6138, Val_acc 0.6500
# Fold: 5, Epoch: 1173, Loss: 1.0626, Train_acc 0.6085, Val_acc 0.6500
# Fold: 5, Epoch: 1174, Loss: 1.0003, Train_acc 0.6085, Val_acc 0.6500
# Fold: 5, Epoch: 1175, Loss: 0.6725, Train_acc 0.6164, Val_acc 0.6667
# Fold: 5, Epoch: 1176, Loss: 1.1742, Train_acc 0.6164, Val_acc 0.6500
# Fold: 5, Epoch: 1177, Loss: 0.8239, Train_acc 0.6164, Val_acc 0.6500
# Fold: 5, Epoch: 1178, Loss: 0.6052, Train_acc 0.6164, Val_acc 0.6500
# Fold: 5, Epoch: 1179, Loss: 0.6914, Train_acc 0.6190, Val_acc 0.6667
# Fold: 5, Epoch: 1180, Loss: 1.1750, Train_acc 0.6296, Val_acc 0.6833
# Fold: 5, Epoch: 1181, Loss: 1.3848, Train_acc 0.6561, Val_acc 0.7167
# Fold: 5, Epoch: 1182, Loss: 0.9422, Train_acc 0.6720, Val_acc 0.7500
# Fold: 5, Epoch: 1183, Loss: 1.0467, Train_acc 0.6931, Val_acc 0.7833
# Fold: 5, Epoch: 1184, Loss: 1.0446, Train_acc 0.6799, Val_acc 0.7667
# Fold: 5, Epoch: 1185, Loss: 0.6320, Train_acc 0.6720, Val_acc 0.7667
# Fold: 5, Epoch: 1186, Loss: 0.9322, Train_acc 0.6746, Val_acc 0.7667
# Fold: 5, Epoch: 1187, Loss: 1.5836, Train_acc 0.7249, Val_acc 0.8333
# Fold: 5, Epoch: 1188, Loss: 0.7509, Train_acc 0.7751, Val_acc 0.8333
# Fold: 5, Epoch: 1189, Loss: 0.9977, Train_acc 0.7989, Val_acc 0.8333
# Fold: 5, Epoch: 1190, Loss: 1.2075, Train_acc 0.8095, Val_acc 0.8500
# Fold: 5, Epoch: 1191, Loss: 1.0259, Train_acc 0.8201, Val_acc 0.8500
# Fold: 5, Epoch: 1192, Loss: 1.2094, Train_acc 0.7989, Val_acc 0.8500
# Fold: 5, Epoch: 1193, Loss: 0.9965, Train_acc 0.7804, Val_acc 0.8333
# Fold: 5, Epoch: 1194, Loss: 0.8350, Train_acc 0.7857, Val_acc 0.8333
# Fold: 5, Epoch: 1195, Loss: 1.1824, Train_acc 0.8307, Val_acc 0.8667
# Fold: 5, Epoch: 1196, Loss: 0.8120, Train_acc 0.8492, Val_acc 0.8833
# Fold: 5, Epoch: 1197, Loss: 0.9686, Train_acc 0.8333, Val_acc 0.8833
# Fold: 5, Epoch: 1198, Loss: 0.9223, Train_acc 0.8307, Val_acc 0.8833
# Fold: 5, Epoch: 1199, Loss: 0.7875, Train_acc 0.8413, Val_acc 0.8833
# Fold: 5, Epoch: 1200, Loss: 0.7715, Train_acc 0.8360, Val_acc 0.8500
# Fold: 5, Epoch: 1201, Loss: 1.1333, Train_acc 0.8175, Val_acc 0.8500
# Fold: 5, Epoch: 1202, Loss: 0.6498, Train_acc 0.7963, Val_acc 0.8500
# Fold: 5, Epoch: 1203, Loss: 1.2324, Train_acc 0.7328, Val_acc 0.8333
# Fold: 5, Epoch: 1204, Loss: 1.0186, Train_acc 0.7037, Val_acc 0.8000
# Fold: 5, Epoch: 1205, Loss: 0.9718, Train_acc 0.6640, Val_acc 0.7333
# Fold: 5, Epoch: 1206, Loss: 0.8148, Train_acc 0.6587, Val_acc 0.7333
# Fold: 5, Epoch: 1207, Loss: 0.8116, Train_acc 0.6693, Val_acc 0.7333
# Fold: 5, Epoch: 1208, Loss: 0.8409, Train_acc 0.6746, Val_acc 0.7333
# Fold: 5, Epoch: 1209, Loss: 1.1113, Train_acc 0.6825, Val_acc 0.7667
# Fold: 5, Epoch: 1210, Loss: 0.5918, Train_acc 0.6958, Val_acc 0.7833
# Fold: 5, Epoch: 1211, Loss: 1.0436, Train_acc 0.7222, Val_acc 0.8333
# Fold: 5, Epoch: 1212, Loss: 1.6913, Train_acc 0.7354, Val_acc 0.8333
# Fold: 5, Epoch: 1213, Loss: 0.9817, Train_acc 0.7646, Val_acc 0.8333
# Fold: 5, Epoch: 1214, Loss: 1.0788, Train_acc 0.7910, Val_acc 0.8333
# Fold: 5, Epoch: 1215, Loss: 0.9014, Train_acc 0.7672, Val_acc 0.8333
# Fold: 5, Epoch: 1216, Loss: 1.0927, Train_acc 0.7328, Val_acc 0.8167
# Fold: 5, Epoch: 1217, Loss: 0.8891, Train_acc 0.6958, Val_acc 0.7667
# Fold: 5, Epoch: 1218, Loss: 1.0281, Train_acc 0.7222, Val_acc 0.7833
# Fold: 5, Epoch: 1219, Loss: 1.0776, Train_acc 0.7143, Val_acc 0.7833
# Fold: 5, Epoch: 1220, Loss: 0.8905, Train_acc 0.7090, Val_acc 0.7833
# Fold: 5, Epoch: 1221, Loss: 0.9399, Train_acc 0.7275, Val_acc 0.8000
# Fold: 5, Epoch: 1222, Loss: 0.8959, Train_acc 0.7963, Val_acc 0.8667
# Fold: 5, Epoch: 1223, Loss: 1.1593, Train_acc 0.8783, Val_acc 0.9333
# Fold: 5, Epoch: 1224, Loss: 0.8957, Train_acc 0.9259, Val_acc 0.9500
# Fold: 5, Epoch: 1225, Loss: 1.0214, Train_acc 0.9312, Val_acc 0.9500
# Fold: 5, Epoch: 1226, Loss: 0.7010, Train_acc 0.8889, Val_acc 0.9333
# Fold: 5, Epoch: 1227, Loss: 1.0810, Train_acc 0.7513, Val_acc 0.8333
# Fold: 5, Epoch: 1228, Loss: 0.9068, Train_acc 0.6931, Val_acc 0.7500
# Fold: 5, Epoch: 1229, Loss: 0.8480, Train_acc 0.6481, Val_acc 0.7000
# Fold: 5, Epoch: 1230, Loss: 1.0174, Train_acc 0.6270, Val_acc 0.6500
# Fold: 5, Epoch: 1231, Loss: 0.9493, Train_acc 0.6349, Val_acc 0.6667
# Fold: 5, Epoch: 1232, Loss: 0.5440, Train_acc 0.6349, Val_acc 0.6833
# Fold: 5, Epoch: 1233, Loss: 1.0563, Train_acc 0.6349, Val_acc 0.6667
# Fold: 5, Epoch: 1234, Loss: 0.9540, Train_acc 0.6402, Val_acc 0.6833
# Fold: 5, Epoch: 1235, Loss: 1.4144, Train_acc 0.6243, Val_acc 0.6667
# Fold: 5, Epoch: 1236, Loss: 0.8026, Train_acc 0.6190, Val_acc 0.6667
# Fold: 5, Epoch: 1237, Loss: 0.7133, Train_acc 0.6190, Val_acc 0.6833
# Fold: 5, Epoch: 1238, Loss: 1.3337, Train_acc 0.6138, Val_acc 0.6833
# Fold: 5, Epoch: 1239, Loss: 0.8656, Train_acc 0.6190, Val_acc 0.6833
# Fold: 5, Epoch: 1240, Loss: 1.2415, Train_acc 0.6190, Val_acc 0.6667
# Fold: 5, Epoch: 1241, Loss: 0.7908, Train_acc 0.6667, Val_acc 0.7333
# Fold: 5, Epoch: 1242, Loss: 0.8295, Train_acc 0.6931, Val_acc 0.7667
# Fold: 5, Epoch: 1243, Loss: 0.6474, Train_acc 0.7063, Val_acc 0.7500
# Fold: 5, Epoch: 1244, Loss: 0.9458, Train_acc 0.6878, Val_acc 0.7333
# Fold: 5, Epoch: 1245, Loss: 0.9766, Train_acc 0.6984, Val_acc 0.7500
# Fold: 5, Epoch: 1246, Loss: 1.1339, Train_acc 0.6852, Val_acc 0.7500
# Fold: 5, Epoch: 1247, Loss: 0.9116, Train_acc 0.6772, Val_acc 0.7667
# Fold: 5, Epoch: 1248, Loss: 1.0322, Train_acc 0.6614, Val_acc 0.7167
# Fold: 5, Epoch: 1249, Loss: 1.0887, Train_acc 0.6825, Val_acc 0.7667
# Mean Validation Accuracy: 0.6857, Std Validation Accuracy: 0.0535

# %%
# Testing phase

test_mask = torch.ones(test_data.num_nodes, dtype=torch.bool)
test_acc, y_pred = test(best_model, test_data, test_mask)
y_true = test_data.y[test_mask]


# Plot the confusion matrix
conf_matrix = confusion_matrix(y_true.cpu().tolist(), y_pred.cpu().tolist())
print(f'Test accuracy: {test_acc:.4f}')
classes = ('LumP', 'Ba/Sq', 'LumU', 'Stroma-rich')
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(conf_matrix_normalized, index=classes, columns=classes)  
sn.heatmap(df_cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix on Test')
plt.show()
# Out:
# Test accuracy: 0.8684
